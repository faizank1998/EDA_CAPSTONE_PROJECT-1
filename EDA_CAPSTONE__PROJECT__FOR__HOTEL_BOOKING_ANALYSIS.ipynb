# %% [markdown]
# # **PROJECT NAME** :- EDA Capstone Project For Hotel Booking analysis

# %% [markdown]
# **Project Type** :- EDA (Exploratory Data Analysis)
#
# **Contribution** :- Individual
#                     (FAIZAN KHAN)

# %% [markdown]
# # **PROJECT SUMMARY :-**

# %% [markdown]
# * Exploratory Data Analysis(EDA) is an approach to analyze the Data Using Visual Techniques.it is used to discover trends,patterns or check assumptions with the help of Graphical Representations.
# * In This Project, i am Going to Begin to Explore the Dataset in Which Hotel Booking Comprises between Two Types of Hotels for Example, City Hotels and Resort Hotels.
# * In This Dataset We Have 119390 Rows, 32 Columns.
# * This DataSets Have Duplicate And Null Values
# * In This DataSets have  31994 duplicate values and four Columns have missing Values
# * In This DataSet Have Float64(4), Int64(16), Object(12) dtype
# * In this Project I have Divided Data manipulation workflow into three different categories (1)Data Collection, (2)Data Cleaning, (3)Data Manipulation and EDA(EXPLORATORY DATA ANALYSIS).
# *Moving Further used Various Basic Functions and Attributes Like Data Collections First Step to find Various Columns Which is done by using various method like Head(), Tail(), info(), describe(), Some Other Method Used For Data Collection.
# *This Dataset Have both Duplicate and Missing Values are available, so need to deal with that and as a result need to replaced the null and missing values to duplicate values also need to dropped.
# * Data cleaning is the process of fixing or removing incorrect, corrupted, incorrectly formatted, duplicate, or incomplete data within a dataset. When combining multiple data sources, there are many opportunities for data to be duplicated or mislabeled. If data is incorrect, outcomes and algorithms are unreliable, even though they may look correct.
# *The Data Type of Reservation_status_date, column was object so it was changed to date type form to better use.
# *Before Visulizing any type of data need to do data wrangling so, for that so we have checked the null value of all the columns, so after completing the data wrangling then moved to the data visualisation part.
# *Then have to started the data visualisation in a structured way while the following 'UBM' rule.
# -'U' - Univariate Analysis.
# -'B' - Bivariate Analysis
# -'M' - Multivariate Analysis
#        * In the data visulisation process, have to used various
#          charts and have to deep understanding the graph to catch
#          the proper insight that give thw bussiness outcome
#        * Then Have also Used the corelation between the diffrent
#          columns that also play avery crucial role in
#          understanding the wholesome relationship the dataset
#        * Thus, have Explored and analyzed the data to discover
#          import that govern the bookings

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **PROBLEM STATEMENT** :-

# %% [markdown]
# **Have you wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate?
# what if you wanted to predict whether or not a hotel likely to receive a disproportionately high number of special requests?This Hotel Booking Dataset can help you explore those questions?This dataset contains booking information for a city hotel and resort hotel and includes information such as when the booking was made,lenght os stays and number of adults,childrens and babies and the number of availabel parking spaces,among other things.All Personally identifying information has been removed from the data here,it is given a hotel booking dataset.this dataset contain booking information for a city hotel and resort hotel.**

# %% [markdown]
# # **GENERAL GUIDELINES** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
import seaborn as sns
import ast

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
file_path = '/content/Hotel Bookings.csv'
hotel_bk_df = pd.read_csv(file_path)
hotel_bk_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First View
hotel_bk_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
hotel_bk_df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Information
hotel_bk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ### Duplicate Values

# %%
# duplicate values count
len(hotel_bk_df[hotel_bk_df.duplicated()])
# Out:
# 31994

# %%
# visualizing duplicate
plt.figure(figsize=(10,8))
sns.countplot(x = hotel_bk_df.duplicated())
# Out:
# <AxesSubplot:ylabel='count'>

# %% [markdown]
# ### Missing Values/Null Values

# %%
# Missing Values/ Null Values
print(hotel_bk_df.isnull().sum().sort_values(ascending = False))
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
# visualizsing the missing values
# checking null value by plotting maps
plt.figure(figsize=(10,10))
sns.heatmap(hotel_bk_df.isnull(), cbar = False, yticklabels= False, cmap = 'viridis')
plt.xlabel("Name of columns", fontsize = 15)
plt.title("Places of missing values in column", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Places of missing values in column')

# %% [markdown]
# # What did you know about your Datasets?

# %% [markdown]
# * This Dataset contain 119390 rows and 32 columns
# * All the Columns Are Divided into three dtypes : float64(4), int64(16), object(12)
# * This Datasets have Duplicate as well as null values. There are Total 31994 duplicate Values.
# * The Maximum number of missing values from 'Company' followed by 'agent' 'country' and 'Children' maximum number of Missing Values from Company are '112593'

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
hotel_bk_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
hotel_bk_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # * **Variable Descripton**
# * hotel : Name of the hotel (Resort Hotel or City Hotel)
# * is_Canceled : if the booking was Cancelled(1) or not (0)
# * lead_time : Numbers of days has elapsed between entering data of the booking into PMS and the arrival Date
# * arrival_date_year : year of arrival date
# * arrival_date_month : month of arrival date
# * arrival_date_week_number : weeek number of arrival date
# * arrival_dat_day : day of arrival date
# * stays_in_wekend_night : number of weekend nights(saturday or sunday)the guest stayed or booked to stay at the hotel
# * stays_in_week_nights : Number in week nights(Monday to Friday)the guest stayed or booked to stay at the hotel
# * adults : Numbers of adults
# * children : Number of children Among Guest
# * babies : numbers of babies Among Guest
# * meal : kind of meal opted By Customer
# * country : Code of respective Country
# * make_segment : Which segment the customer belongs to
# * Destribution_channel : How the customer accessed the stay-corporate booking/direct/TA.TO.(TA : travel agent, TO : Tour Operator)
# * is_repeated_guest : guest coming for the fist time or not
# * previous_cancellation : was there a cancellation before
# * previous_ bookings : count of previous booking
# * resevered_room_type : code of room type resevered
# * assigned_room_type : code of room type assigned
# * booking_changes : count of changes made to booking
# * deposit_type : Type of deposit made by the guest
# * agent : booked through agent
# * days_in_waiting_list : number of days in waiting list
# * customer_type : Type of customer Arrived.
# * required_car_parking : if car parking required.
# * total_of_special_req : Number of special requirement by customers
# * reservation_status : Reservation Status(cancelled, check-out, no show
# * reservation_status_date : Date of last reservation status

# %% [markdown]
# # Check Unique Values For Each Variables

# %%
# check Unique Values for Each Variables
for elem in hotel_bk_df.columns.tolist():
  print("No. of unique values in", elem, "is", hotel_bk_df[elem].nunique() )
# Out:
# No. of unique values in hotel is 2
# No. of unique values in is_canceled is 2
# No. of unique values in lead_time is 479
# No. of unique values in arrival_date_year is 3
# No. of unique values in arrival_date_month is 12
# No. of unique values in arrival_date_week_number is 53
# No. of unique values in arrival_date_day_of_month is 31
# No. of unique values in stays_in_weekend_nights is 17
# No. of unique values in stays_in_week_nights is 35
# No. of unique values in adults is 14
# No. of unique values in children is 5
# No. of unique values in babies is 5
# No. of unique values in meal is 5
# No. of unique values in country is 177
# No. of unique values in market_segment is 8
# No. of unique values in distribution_channel is 5
# No. of unique values in is_repeated_guest is 2
# No. of unique values in previous_cancellations is 15
# No. of unique values in previous_bookings_not_canceled is 73
# No. of unique values in reserved_room_type is 10
# ...

# %%
# checking the values of categorial columns by one by one
#1 checking the values in hotel column
hotel_bk_df['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
#checking unique values arrival dates in "arrival_date_year" column
hotel_bk_df['arrival_date_year'].unique()
# Out:
# array([2015, 2016, 2017])

# %%
# checking unique values in "canceled" column
hotel_bk_df['is_canceled'].unique()
# Out:
# array([0, 1])

# %%
# Checking unique values in "meal" column
hotel_bk_df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
# Checking unique values in "distribution_channel" column
hotel_bk_df['distribution_channel'].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'Undefined', 'GDS'], dtype=object)

# %%
# Checking unique values in "market segment" column
hotel_bk_df['market_segment'].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Undefined', 'Aviation'], dtype=object)

# %%
# Checking uinque values in "children" column
hotel_bk_df['children'].unique()
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
 # Write your code to make dataset ready analysis basis
 # Missing values in columns
 hotel_bk_df.isnull().sum().sort_values(ascending = False)[:6]
# Out:
# company               112593
# agent                  16340
# country                  488
# children                   4
# reserved_room_type         0
# assigned_room_type         0
# dtype: int64

# %%
hotel_bk_df[['company', 'agent', 'children']] = hotel_bk_df[['company', 'agent','children']].fillna(0)
hotel_bk_df[['country']] = hotel_bk_df[['country']].fillna('other')

# %%
# Checking all null values is removed
hotel_bk_df.isnull().sum().sort_values(ascending = False)[:6]
# Out:
# hotel                          0
# is_canceled                    0
# reservation_status             0
# total_of_special_requests      0
# required_car_parking_spaces    0
# adr                            0
# dtype: int64

# %%
# checking the duplcate values in datasets
len(hotel_bk_df[hotel_bk_df.duplicated()])
# Out:
# 31994

# %%
# Dropping the duplicates Rows
hotel_bk_df = hotel_bk_df.drop_duplicates()

# %%
# checking the shape of dataset whose combining values of adults,babies and childrens columns is 0
hotel_bk_df[hotel_bk_df['adults']+ hotel_bk_df['babies']+ hotel_bk_df['children'] == 0].shape
# Out:
# (166, 32)

# %%
hotel_bk_df.shape
# Out:
# (87396, 32)

# %%
# dropping the rows where combining the values of adults, childrens and babies columns is 0 because of no booking was made
hotel_bk_df.drop(hotel_bk_df[hotel_bk_df['adults']+ hotel_bk_df['babies']+ hotel_bk_df['children'] == 0].index,inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# # **converting column to Appropriate datatypes**

# %%
# changing datatype column 'reservation_status_date' from object to data type
hotel_bk_df['reservation_status_date'] = pd.to_datetime(hotel_bk_df['reservation_status_date'], format = '%Y-%m-%d')
# Out:
# <ipython-input-28-f3a35c982349>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_bk_df['reservation_status_date'] = pd.to_datetime(hotel_bk_df['reservation_status_date'], format = '%Y-%m-%d')

# %% [markdown]
# # **Adding import columns**

# %%
# adding No. of days stayong in hotel
hotel_bk_df['total_stay'] = hotel_bk_df['stays_in_week_nights']+ hotel_bk_df['stays_in_week_nights']

# adding total no. of people num as column, i.e. total types of person = num of adults + children + babies
hotel_bk_df['total_people'] = hotel_bk_df['adults']+ hotel_bk_df['children']+ hotel_bk_df['babies']
# Out:
# <ipython-input-30-591700b5d58e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_bk_df['total_stay'] = hotel_bk_df['stays_in_week_nights']+ hotel_bk_df['stays_in_week_nights']
# <ipython-input-30-591700b5d58e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_bk_df['total_people'] = hotel_bk_df['adults']+ hotel_bk_df['children']+ hotel_bk_df['babies']

# %%
# checking final numbers of rows and columns
hotel_bk_df.shape
# Out:
# (87230, 34)

# %% [markdown]
# ##  What all Manipulation  have you done and insight you found?

# %% [markdown]
# We have done the following manipulation insight found by as follows:-
#
# * we have found there were 4 columns containing Null values : Company, agents, country and children.
# 1. so for company and agents we have filled the missing values with 0
# 2. as the count of missing values of children is only 4
# * this datasets also containig duplicate values so the duplicate values is dropped.
# * we found the combining values of children, adults and babies was 0 so we dropped them, after all combinig the values of children, adults, and babies of rows and columns was dropped
# * the data type of 'reservation _status_date was object changed into date type format for bettr use
# *that is two columns were added first is 'total_people and other is 'total_stay'.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# # **Chart - 1:- Pie Chart for most preferred Hotel(Univariate)**

# %%
# Visulaising by pie-chart
hotel_bk_df['hotel'].value_counts().plot.pie(explode=[0.05, 0.05], autopct= '%1.1f%%', shadow = True, figsize=(10,9),fontsize =21)
plt.title('pie chart for most preferred hotel', fontsize=15)
# Out:
# Text(0.5, 1.0, 'pie chart for most preferred hotel')

# %% [markdown]
# # Why did you picked Specific Chart?

# %% [markdown]
# * The Pie-Chart is expressed the whole relationship of the data.it is very easy to explain the percentage comparison through area covered in a Circle with diffrent colors. wherever percentage comparison comes into action so frquently used pie- chart.

# %% [markdown]
# # What are insight found from the chart

# %% [markdown]
# * From the above Chart, we get to know that City Hotel is most preferred hotel by guests.thus city hotel has maximum bookings 61.1% guests preffered city hotel while 39.9% guests preffered Resort Hotel.

# %% [markdown]
# #  will gained positive impact for bussiness ideas?

# %% [markdown]
# * City Hotel Doing very well so they are providing more services for attracting more guest to increases his revenue, so they are doing really well but in case of resort hotel guest have shown less interest than city hotel so resort hotel need to find our better solution for attracting more guest and find what city hotel has done to attract guests, so there is very high scope of growth of resort hotel if they upgrade their service and adopt there better way

# %% [markdown]
# # Chart - 2 :- Hotel type with highest adr(Bivariate with Categorial - numerical

# %%
# group by hotel
grp_by_hotel = hotel_bk_df.groupby('hotel')

# %%
# grouping by hotel adr
highest_adr = grp_by_hotel['adr'].mean().reset_index()

#set plot size
plt.figure(figsize = (10,8))

# set labels
plt.xlabel('hotel type', fontsize = 15)
plt.ylabel('ADR', fontsize = 15)
plt.title('average ADR of each hotel type', fontsize = 15)

#plot graph
sns.barplot(x = highest_adr['hotel'], y = highest_adr['adr'])
# Out:
# <AxesSubplot:title={'center':'average ADR of each hotel type'}, xlabel='hotel', ylabel='adr'>

# %% [markdown]
# # Why did you pick the specific Chart

# %% [markdown]
# * Because the bar chart is how the frequency counts of values for the different levels of a categorial or nominal variable.
# * to showing the average adr of each hotel type in a clear or feasible way. so we have used bar chart

# %% [markdown]
# # What are the insight found from the chart

# %% [markdown]
# * City Hotel has highest Adr.That Means City hotel is generating more revenue than resort hotel.
# * so the city hotel has can do more advertising to get nore revenue.Thus the city hotel are already enjoying high adr but bit more of positive efforts towards more definitely add alot to their growth and overall revenue.

# %% [markdown]
# # **Chart -3 :- relationship between Adr and Total Stay(Bivariate with numerical-numerical**

# %%
# Chart - 3 Visualisation Code
# Groupy adr, total, hotel
adr_vs_stay = hotel_bk_df.groupby(['total_stay', 'adr', 'hotel']).agg('count').reset_index()
adr_vs_stay = adr_vs_stay.iloc[:, :3]
adr_vs_stay = adr_vs_stay.rename(columns = {'is_canceled' : 'number of stays'})
adr_vs_stay = adr_vs_stay[: 18000]
adr_vs_stay
# Out:
#        total_stay     adr         hotel
# 0               0    0.00    City Hotel
# 1               0    0.00  Resort Hotel
# 2               0    3.00    City Hotel
# 3               0    4.00  Resort Hotel
# 4               0    5.00  Resort Hotel
# ...           ...     ...           ...
# 17995          10  208.41    City Hotel
# 17996          10  208.43  Resort Hotel
# 17997          10  208.48  Resort Hotel
# 17998          10  208.57  Resort Hotel
# 17999          10  208.67  Resort Hotel
#
# [18000 rows x 3 columns]

# %%
# plotting the graph in line chart
plt.figure(figsize = (16,8))
sns.lineplot(x = 'total_stay', y = 'adr', data = adr_vs_stay)
plt.xlabel('total_stay', fontsize = 15)
plt.ylabel('adr', fontsize = 15)
plt.title('Relationship between adr and total stay', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Relationship between adr and total stay')

# %% [markdown]
# # Why did you pick the specific chart?

# %% [markdown]
# * This is a line chart and its help to show small shift that may be getting hard to spot in other graphs it helps to shows a differnt trends.

# %% [markdown]
# # What are the insight from the chart?

# %% [markdown]
# From this chart we have found that as the total stay increases the adr also increases  so, adr is directly proportional to the total_stay.

# %% [markdown]
# # Will gained the insight help to creating a bussiness impact

# %% [markdown]
# * The hotel should focus on increasing thier Adr and more advertisement and better facilities and good offers will let the guests to stay more that will directly result in increasing edr. so, Hotels should offer more attractive offers and facilities so that total stay can be increased that will directly multiply their edr and ultimately will increases

# %% [markdown]
# # Chart-4 :- Percentage of Repeated Guests (Univariate)

# %%
# Chart-4 Visualisation Code
hotel_bk_df['is_repeated_guest'].value_counts().plot.pie(explode=(0.05,0.05),autopct='%1.1f%%',shadow=True, figsize = (12,8),fontsize = 20)
plt.title("Percentage (%) of repeated guest", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Percentage (%) of repeated guest')

# %% [markdown]
# # Why did you pick the specific chart?

# %% [markdown]
# Pie Chart is used to represent the proportional data or relative data in a single chart. The Concept of pie slices is used to show the percentage of a particular data from a whole pie.

# %% [markdown]
# # What are the Insight From the Chart?

# %% [markdown]
# Repeated Guest are very less which is only 3.9% while 96.1% guests are not returning to the same hotel So, it is amtter of deep thinking and taking proper step to increases a repeated guest numbers. In Order to retained the guests management should take feedback from the guests and try to impress with his Sevices.

# %% [markdown]
# # Will gained the insight help to creating a bussiness impact

# %% [markdown]
# it's True the Repeated guests are very less, so if the hotel will work on his side also to increase his repeated guest will ultimately they will boost his revenue so, they need to take right step should be taken feedback from then finding problems and solving customers problems within a time and offering him best services and offers to the Customers.

# %% [markdown]
# # **Chart - 5 :- Percentage Distribution Of required_car_parking_spaces (Univariate)**

# %%
# Visualisation Code
hotel_bk_df['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5, autopct ='%1.1f%%', shadow=False,figsize=(12,8),fontsize = 15,labels = None)
labels = hotel_bk_df['required_car_parking_spaces'].value_counts().index
plt.title('%distribution of required car parking spaces', fontsize = 15)
plt.legend(bbox_to_anchor=(0.05,1), loc= 'upper left' , labels = labels)

# %% [markdown]
# # Why did you pick The Specific Chart?

# %% [markdown]
# We Have Used Pie Chart beacause it gives the output in more Understanding manner as here we can clearly see the different two colors reflecting the Demand of car parking spaces by guests. so it's very useful chart to get proper insight as we can use other chart also but we have fount it more relevent here.

# %% [markdown]
# # What are the insight found from the chart ?

# %% [markdown]
# This chart shows that 91.6% guests did not required the parking spaces. only 8.3% guests required only parking spaces

# %% [markdown]
# # Will gained the insight help to creating a bussiness impact

# %% [markdown]
# yes that insight definetely help the hotel to provide better services.it can be said that hotels need to work less on car parking spaces as only 1 car parking spaces were required by 8.3% guest. so it is better to have a limited car parking spaces and use that spcaes for other important purpose rather than just leeting go unused. so it is better to focus on other areas to increase quality of hotel rather than focusing mainly on car parking area only.the demand of car parking area is less . this might be the reason as too many guests prefer to use public vehicles to travel.

# %% [markdown]
# # **Chart:-6 - Meal Type Distribution(Univariate)**

# %%
# Visualization Code 
plt.figure(figsize=(16,7))
sns.countplot(x=hotel_bk_df['meal'])
plt.xlabel('meal type',fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.title('preferred meal type',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'preferred meal type')

# %% [markdown]
# # Why did you pick the specific Chart?

# %% [markdown]
# We have used this count plot beacuse it Shows the count of categorial bin using bars. bar pots look similar to Count plots.But instead of using count plots of observation in each category. they shows the means of a quantative variable among observation in each category. so we have used this count plots.

# %% [markdown]
# # What are the insight found from the chart?

# %% [markdown]
# Inside the chart we found the meals which is most preferred by the guests is BB(Bed and Breakfast) while HB(Half board) and SC (self catering) are equally preferred. types of meals are as follows:
#
# BB-(bed and breakfast) HB-(Half Board) FB-(Full -Board) SC -(Self- Catering)

# %% [markdown]
# # Will gain the Insight Help To careating the bussiness ideas?

# %% [markdown]
# So, the insight has positive impact of hotes needs to focus more on the BB meal type so that the majority of customers are satisfied while others tpes of meals should be given equal importance with proper management of food services so as the guests we nned to give best offer or services to customers.

# %% [markdown]
# # *Chart:-7 - Pie Chart For Mostly used for Distribution Channels and relationship of Distribution channel and Adr *

# %%
# Chart:-7 Visualising with the help of pie chart for mostly used Distribution channel

# Recreating labels
labels = hotel_bk_df['distribution_channel'].value_counts().index.tolist()

# creating new df of distribution_channel
distribution_channel_df = hotel_bk_df['distribution_channel'].value_counts().reset_index().rename(columns = {'index':'distribution_channel', 'distribution_channel':'count'})

# adding percentage column to distribution_channel_df
distribution_channel_df['percentage']=round( distribution_channel_df['count']*100/hotel_bk_df.shape[0],1)

# creating list of percentage
sizes = distribution_channel_df['percentage'].values.tolist()

#plotting the pie chart
hotel_bk_df['distribution_channel'].value_counts().plot.pie(explode = [0.05,0.05,0.05,0.05,0.05], shadow=False, figsize=(15,8),fontsize=10, labels =None)

# Seting legends with the percentage values
labels = [f'{1}, {s}%' for l, s in zip(labels, sizes)]
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels = labels)
plt.title('mostly used distribution channel for hotel bookings', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'mostly used distribution channel for hotel bookings')

# %%
# chart - 7 visualization code to check relationship between adr and distribution channel 
#using group by on distribution_channel and hotel
distribution_channel_df = hotel_bk_df.groupby(['distribution_channel', 'hotel'])['adr'].mean().reset_index()

# set plot size and plot barchart
plt.figure(figsize = (16,8))
sns.barplot(x='distribution_channel', y ='adr', data = distribution_channel_df, hue = 'hotel')
plt.title('ADR across Distribution channel')
# Out:
# Text(0.5, 1.0, 'ADR across Distribution channel')

# %% [markdown]
# # Why did you pick the specific chart?

# %% [markdown]
# in the first visualization,we have used the pie chart for understanding of mostly used booking channel with occupancy percentage of each booking Channel. A pie Chart expresses a part to whole relationship in your data. it is easy to explain the percentage comparison through area was covered in a circle with different colors. while different percentage comparison comes into action pie-chart is used frequently.so, we have used pie chart and pie-chart which helped me to percentage comparison on the dependent value.
#
# while in 2nd visulaization bar chart are used.bar charts show the frequency counts of values for the different levels of a categorial or nominal variable. sometimes, bar chart shows othe states

# %% [markdown]
# # What are the insight found from the charts?

# %% [markdown]
# From the above 1st Chart, we have found that 'TA/TO' has been mostly (79.1%) used for booking hotels. direct constitues of 14.9%.Corporates Constitutes of 5.8% GDS Constitutes of only 0.2% and rest unidentified are 0.
#
# From the above 2nd Chart it is clear that 'direct' and 'TA/TO' have almost equally contribution in adr on both type 'hotels' While GDS has highly Contributed in adr in both type of 'city hotels' type. GDS needs to increase Resort Hotel Bookings. Corporate these are Corporate hotel Booking Companies  which makes booking possible. the definition of abbreviation used in this graph are as follows:
#
#  * GDS-A GDS is a worldwide contact between travel bookers and suppliers, Such as hotels and other accomodation Providers.It communicate live product,price and availibility Data to Travel Agents and online Booking Engines, And Allows for automated
#  transaction.
#  * Direct Means that Bookings are Directly Made with the respective Hotels.
#  *TA/TO means that Bookings Are throught travel agents and travel operator.
#  * Undefined Bookings are undefined it may be the reason that customers made their bookings on arrival.

# %% [markdown]
# # Will gained the insight help positve bussiness ideas?

# %% [markdown]
# So from this 1st Graph, We Have got the insight that TA/TO is the leading one while Direct and Coporates have the potential to grow as they occupy much less spaces than the leading one . so good understanding and relation of hotel with TA/TO will Definately add up to growth and revenue.
#
# yes the gained from 2nd Visualization will definately help different distribution channel to work on the spaces where they are lacking behind like GDS is Dominating in terms of adr in case of City Hotels but lacking behind in Resorts Hotel , so just taking a proper step to in the right descision will help to increase the Overall Revenue.

# %% [markdown]
# # Chart - 8:- Booking By month and optimal stay lenght in hotels

# %%
# chart - 8:- visualization code
#using groupby on arrival_date_month and taking the hotel count
bookings_by_months_df = hotel_bk_df.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':'Counts'})
# create a list of months in order 
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October','November','December']
# creating df which will map the order of above months list without changing its values 
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
# sorting by arrival_date_month
bookings_by_months_df = bookings_by_months_df.sort_values('arrival_date_month')

bookings_by_months_df
# Out:
#    arrival_date_month  Counts
# 4             January    4685
# 3            February    6083
# 7               March    7489
# 0               April    7900
# 8                 May    8344
# 6                June    7756
# 5                July   10043
# 1              August   11242
# 11          September    6682
# 10            October    6921
# 9            November    4973
# 2            December    5112

# %%
#set plot size 
plt.figure(figsize = (20,8))

# plotting lineplot on x - months & y - booking counts
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['Counts'])

#set title for the plot
plt.title('numbers of bookings across each month', fontsize = 15)
# set x label 
plt.xlabel('month',fontsize = 15)
# set y label
plt.ylabel('numebers of bookings', fontsize = 15)
# Out:
# Text(0, 0.5, 'numebers of bookings')

# %%
# Chart - 8 Visualisation Code 
# using groupby function on total stay and hotel
stay = hotel_bk_df.groupby(['total_stay', 'hotel']).agg('count').reset_index()
stay = stay.iloc[:, :3]
# renaming the columns
stay = stay.rename(columns={'is_canceled': 'Number of stays'})

# %%
# setting the plot and barchart
plt.figure(figsize = (18,9))
sns.barplot(x='total_stay',y = 'Number of stays', hue='hotel',data = stay)

#set labels
plt.title('Optimal Stay length in each hotel types',fontsize = 15)
plt.ylabel('count of stays',fontsize = 15)
plt.xlabel('total_stay(days)',fontsize = 15)
# Out:
# Text(0.5, 0, 'total_stay(days)')

# %% [markdown]
# # Why did you pick the specific chart?

# %% [markdown]
# fo 1st Chart we have picked the line char here because it helps to show small shifts may be getting hard to spot in other graphs.it helps show trends for different periods. in this we easily track the numbers of booking with respect to month.
#
# While in 2nd we have use barplot we used this chart to get clear view understanding the relation between total stay in terms of days and count of stays.(it means total numbers of customers stayed).

# %% [markdown]
# # What are the insight found from the Chart?

# %% [markdown]
# From the first chart found most numbers of booking in the month of july and august. as august and july is come near to the summer vacation, so the summer vacation the reason for the most numbers of bookings.
#
# While From the Second Chart Givess diffrent insight, so from the above observation we have found the optimal stay in both type hotel is less than 7 days so after staying number is drastically Declined.

# %% [markdown]
# # Will gained the insight help positve bussiness ideas?

# %% [markdown]
# From the first chart is clear that yes this provide a good insight that hotels should be well prepared for the month of july and august as maximum booking takes place for this month so, better the preparation and approach will definately adds to the growth of hotels.
#
# in second chart also have positive impact.yes, from the insight gathered here, hotel can work in the domain increases the staying length of customers to increase their revenue. The Other understanding the customers usually prefer a one week in a hotel so hotel need to work efficiently in these seven days, so customer will return the same hotel again so this will increase the revenue.

# %% [markdown]
# # **Chart :-9 - Plotting Histogram**

# %%
# Plotting Histogram 
hotel_bk_df.hist(figsize=(23,18))
plt.show()

# %% [markdown]
# # Why did you pick the specific chart?

# %% [markdown]
# To understand the data in clear way with proper insights we have used histogram here.This Histogram is a popular graphing Tool.It is used to summarize descrete or continuous data that are measured on a interval scale. it is ofetn used to illustrate the major features of the distribution of the data in a convenient form. it is also useful when dealing with large data sets (greater than 100 observations).It can help detect any whole dataset whether it is symmetric or not.

# %% [markdown]
# # What are the insight found from the Chart?

# %% [markdown]
# some insights are found from the chart are as follows:
#
# * we can see maximum guest come in the year of 2016.
# * maximum week number is 30.
# * maximum arrival happen in the last of the month.
# * maximum guest come with no children.
# * there is ver less requirement of car parking.

# %% [markdown]
# # Will gained the insight help positve bussiness ideas?

# %% [markdown]
# Histogram Cannot define bussiness impact. it is just to see the distribution of the column data over the dataset.

# %% [markdown]
# # **Chart :- 10- Year and Hotel wise confirmed booking and cancellation Distribution**

# %%
# Find out the percentage and counts of confirmed and cancelled Bookings.
# plot a Count Plot Chart using seaborn for count of confirmed and cancelled Bookings
plt.figure(figsize = (12,5))
sns.countplot(x='hotel',hue='is_canceled', palette='Set2', data = hotel_bk_df)
plt.legend(['confirmed', 'canceled'])
plt.title('hotel wise confirmation and cancellation of the bookings', fontsize = 18)
plt.ylabel('count of confirmation and cancellations', fontsize = 15)
plt.xlabel('hotel',fontsize = 15)
# Out:
# Text(0.5, 0, 'hotel')

# %%
# removing cancelled bookings from the data and creating new dataframe
data_not_canceled = hotel_bk_df[hotel_bk_df['is_canceled']==0]
#year wise bookings of hotels 
sns.set_style(style = 'darkgrid')
plt.figure(figsize =(12,5))
sns.countplot(x='arrival_date_year', hue = 'hotel', palette= 'tab10', data = data_not_canceled)
plt.legend(['Resort Hotel', 'City Hotel'])
plt.title("year wise bookins of hotels", fontsize = 18)
plt.ylabel('Number of Bookings',fontsize = 15)
plt.xlabel('Year', fontsize = 15)
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# # Why did you pick the specific chart?

# %% [markdown]
# we have out the count plot to get proper insight on hotel wise cancellation and confirmation of bookings

# %% [markdown]
# # What are the insight found from the chart?

# %% [markdown]
# we can clearly seen above the graph that having city hotel is having greater number of bookings as compared to Resort Hotel.
#
# From the the above graphs, it can be summarized that the year 2016 both the hotel saw massive increases their Booking and by far the year 2016 is the year of highest booking of both hotel. In each Year that is 2015,2016 and 2017 the city hotel is having the highest number of bookings.

# %% [markdown]
# # Will gained the insight help positve bussiness ideas?

# %% [markdown]
# Overall the graph shows a poistive outcome but the visulaisation of cancellation Graphs creates a sitution of ddep concern. so here we can see that more than 1/4th of overall booking got cancelled. So it's matter of deep concern.Thus, we can need to look over this problem.The Solution to this problem is that we can check the reason of cancellation of booking and nned to get this sorted out as soon as possible at the bussiness level to stop the problem getting Broader.

# %% [markdown]
# # **Chart-11:- ADR across different Month**

# %%
# Chart-11:- Visualization Code 
#using Groupby function
bookings_by_months_df=hotel_bk_df.groupby(['arrival_date_month', 'hotel'])['adr'].mean().reset_index()
#create month list
months =['January','February','March','April','May','June','July','August','September','October','November','December']
# it will take the order of the month list 
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
# Sorting the values 
bookings_by_months_df = bookings_by_months_df.sort_values('arrival_date_month')
bookings_by_months_df
# Out:
#    arrival_date_month         hotel         adr
# 8             January    City Hotel   85.269875
# 9             January  Resort Hotel   49.181693
# 6            February    City Hotel   89.266427
# 7            February  Resort Hotel   54.102809
# 15              March  Resort Hotel   57.590889
# 14              March    City Hotel   95.193911
# 0               April    City Hotel  117.314134
# 1               April  Resort Hotel   79.283805
# 17                May  Resort Hotel   80.551101
# 16                May    City Hotel  128.055724
# 13               June  Resort Hotel  112.380859
# 12               June    City Hotel  123.996416
# 11               July  Resort Hotel  156.166914
# 10               July    City Hotel  120.318314
# 3              August  Resort Hotel  187.566659
# 2              August    City Hotel  125.148662
# 22          September    City Hotel  118.764693
# 23          September  Resort Hotel  100.892331
# 20            October    City Hotel  107.585401
# ...

# %%
# setting plot size and plotting the line
plt.figure(figsize = (20,8))
sns.lineplot(x=bookings_by_months_df['arrival_date_month'], y = bookings_by_months_df['adr'],hue=bookings_by_months_df['hotel'])

#setting labels
plt.title('ADR across each month',fontsize = 15)
plt.xlabel('Month', fontsize = 15)
plt.ylabel('ADR', fontsize = 15)
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# # Why did you pick the specific chart?

# %% [markdown]
# We Have pick line chart to get the  clear ADR by The City and Resort Hotels Across each month,Line Chart is very useful because it helps to shows small shifts that may be getting hard to spot in other graphs. it help show trend for different periods.they are easy to understand to compare data, more than one line can be plotted the same axis.

# %% [markdown]
# # What are the insights found from the chart?

# %% [markdown]
# * for Resort Hotel,ADR is high in the months of june,july,august as compared to city Hotels.The Reason may be that Customers/people want to spend their Summer Vacation In Restorts Hotels.
#
# * Best Time for guest to visit Resort or City Hotel is January, february, march, april, october,november,and December as the average daily rate of this months is very low. so it would be feasible and sustainable.

# %% [markdown]
# # Will gained the insight help positve bussiness ideas?

# %% [markdown]
# So, the Higher ADR, The Higher willbe revenue so it's a good sign.Hotels should work more to enhance their adr by offering good schemes to attract customer in winter vacation also and no other holidays.

# %% [markdown]
# # **Chart-12:- Weekly Stay Distribution and Calculation and Non-Calculation**

# %%
#Chart 12 :-
#adding total stayings days in hotels
hotel_bk_df['total_stay'] = hotel_bk_df['stays_in_weekend_nights']+hotel_bk_df['stays_in_week_nights']
#using a violin plot to know in which weeks,visitors stays the most
plt.figure(figsize=(18,8))
sns.violinplot(x='arrival_date_week_number', y='total_stay',palette = 'Set2',data=hotel_bk_df)
plt.title('Week wise number os stays', fontsize = 18)
plt.ylabel('Numbers of stays', fontsize = 15)
plt.xlabel('Week Number', fontsize = 15)
# Out:
# <ipython-input-51-5534c5c002a6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_bk_df['total_stay'] = hotel_bk_df['stays_in_weekend_nights']+hotel_bk_df['stays_in_week_nights']
# Text(0.5, 0, 'Week Number')

# %%
# Chart:- 12 Visualiztion Code:-
hotel_bk_df['is_canceled'].value_counts().plot.pie(explode=[0.05,0.05],autopct='%1.1f%%',shadow = True, figsize =(10,8),fontsize = 20)
plt.title('Cancellation and Non-Cancellation', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Cancellation and Non-Cancellation')

# %% [markdown]
# # Why did you pick the Specific Chart?

# %% [markdown]
# We have used here the violin plot to gather proper relation between no of stays and week wise number of stays and violin plots are used when one want to observe the distribution of numeric data, and are specially useful when you want to make a comparison of disrtibution between multiple groups.The peaks, valley and tails of each groups density curve can be compared to see where groups are similar or different.

# %% [markdown]
# # What are the insight found from the Chart?

# %% [markdown]
# From the above Violin plot,we have found that from the week 28 and week 31.it is shown the highest days of stay whereas from the week 1 to 11 has shown a very steady trend in the number of stays and also the week 18 to 22 has the least number of stays by the visitors in aggregate of all 3 years 2015, 2016 and 2017.
#
# From the graph , we have found insight the more than 1/4th of the overall bookings i.e approx 27.5% of the tickets was got cancelled.

# %% [markdown]
# # Will gained the insight help positve bussiness ideas?

# %% [markdown]
# So, here as we can see that more than 27% booking got cancelled so, it's matter of deep concern.Thus,we need to look over this problem. The solution to this problem is that we can check the reason of cancellation of a booking & need to get this sorted out as soon as possible at the bussiness level to stop the problem to gettrin braoder

# %% [markdown]
# # **Chart :-13- Room type preference and Customer Types**

# %%
# Chart :- 13- Visualization Code 
#Set Plot size 
plt.figure(figsize = (18,8))

#plotting 
sns.countplot(x=hotel_bk_df['assigned_room_type'],order=hotel_bk_df['assigned_room_type'].value_counts().index)
plt.xlabel('Room Type',fontsize = 15)
plt.ylabel('Count of Room Type ', fontsize = 15)
plt.title('Most Preffered Room Type', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Most Preffered Room Type')

# %%
#suing seaborn to plot a count chart to demonstrate the types of customers visits the most
plt.figure(figsize= (12,5))
sns.countplot(x='arrival_date_month', hue= 'customer_type', data =hotel_bk_df)
plt.ylabel('Months', fontsize = 15)
plt.xlabel('Number of Customers', fontsize = 15 )
# Out:
# Text(0.5, 0, 'Number of Customers')

# %% [markdown]
# # Why did you Pick The Specific Chart?

# %% [markdown]
# for, 1st Visualization, We have picked the  bar chart to display result for this set of code, here i have used bar graph to show the distributed by volume(count of room), Which type room alloted here summarize the large set of data in a simple form.
#
# from 2nd visualization Chart Involve Count plot it help the number of insights and visualization to easy to following chart.

# %% [markdown]
# # What are the insight found from the Chart?

# %% [markdown]
# From the first Count Plot We got data most prefer Type A so majurity og guest have shown interest to this Room.
#
# From the above graph it can be measured that the transcient type of customers visits the most comes in the category of least visitors.

# %% [markdown]
# # Will gained the insight help positve bussiness ideas?

# %% [markdown]
# yes From the graph we got positive impact because 'A','D','E' Most Prefered due to better service offer by in room type. So Overall Booking in a hotel Manner.
#
# offcourse the better understanding regarding the different type guests will help to take proper right steps towards services facilities,requirement and offers which will directly results in the growth in bussiness.

# %% [markdown]
# # **Chart:- 14 - Chart Correlation Heatmap**

# %%
#  Correlation Heatmap viualization code 
plt.figure(figsize = (19,11))
sns.heatmap(hotel_bk_df.corr(),annot = True)
plt.title('Co-relation of the columns', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Co-relation of the columns')

# %% [markdown]
# # Why did you pick the specific Chart?

# %% [markdown]
# a Co-relation matrix is a table showing corealtion co-efficient between variables.each in cell in the table corelation between two variables
#
# Thus to know about the corelation between all the variables along with the corelation coefiicient, we have used corelation heatmap.

# %% [markdown]
# # What are the Insight Found From the graph?

# %% [markdown]
# The Insight found from the charts are as follows:
#
#       - is_canceled and total stays are negative corelated .this customer unlikely to cancel their booking.if they don't get the same as they reserved room
#
#       - lead_time and total_stay is positively corelated. this mean more the customer more will be lead time
#
#       - adult,childrens and babies are correlated with each other. this inducates more the people more will be adr
#
#       - is_repeated guests and previous booking not_cancel have a strong corelation. This may be due to the reason that repeated guests not more interested to cancel their Bookings.
#
#       - so these are some more powerful insight found from the chart of corelation heatmap.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# ## Suggestion for the client to achieve Bussiness Obejective?
#   Explain Beiefly

# %% [markdown]
# Bussiness Objective attained as follows:
#
# *   To Attain high growth and more success, hotel bussiness need to flourish and for that few things which we need to consider high revenue generation, customers satisfaction and employee retention.
# *   We are able to achieve the same by showing the client which are the month is high revenue generation by using various charts and graphs distribution.
# *   Enhancing the revenue adopted by bar chart distribution of which type room are most prefered and resevered and which are the months suitable for visitors
# *   we also have founded the various prefernce in different categoris like meal type,optimal stay length,facilities require by customers like car parking spaces,etc. so this all insight need to better planning for growth and revenue.
# *   So preparing well by understanding these all the outcomes, the client can be well prepared in advance so that minimum greivances would be faced by clients in long run and would help in further enhancement of their hospitality and service.
# *  Ask feedback often from the guests visiting the hotels so the quality can be upgraded to the next level to increase more guests.
# *  Periodically trhow offers to attract the old customers so as to increase the no of repeated guests.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *  City Hotel are most preffered hotel by the guest,So we can say that City Hotel is busiest hotel in comparison of the resort hotel.
# *  The average ADR of city hotels is higher as compared to Resort hotel, so it can easily said that city hotel is generating more revenue than resort hotels.
# * the total number os stay is directly proportional to adr.so the number of stay is higher then higher will be adr and revenue as well.
# * The percentage of repeated guest is very low. only 3.9% people revisited the hotels and rest 96.1% were new guests.so the retention rate is much low
# *  Among the different types of meals,BB(bed and breakfast) is the most preferred meals by the guests.so the guests is loved to opt. this type meals.
# *  Direct and TA/TO have equally contribution in adr in both types of hotel , City Hotels and Resorts Hotels.
# *  Optimal stay lenght in both hotels (City hotels and Resort Hotels) is less than 7 days. Usually people stays for a week after 7 days optimal stay length is declined drastically.
# *  most numbers of bookings have taken place in the month of july and august.
# *  The Mostly Used distribution channel for bookings is TA/TO is 79.10% Booking were made through TA&TO(travel agents and Tour Operators)
# *  1/4th of the total booking is cancelled.Approx 27.5% have got cancelled out of all bookings.
# *  Majority of guests have shown interest in the room type 'A'. Room type 'A' is the most prefferd Room type.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
